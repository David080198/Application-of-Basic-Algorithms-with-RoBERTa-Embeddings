# %% [markdown]
# ## Para regresión logistica

# %%
import os
directorio_actual_1 = os.getcwd()
# Ruta de la carpeta que deseas explorar
ruta_carpeta = directorio_actual_1

# Recorrer la estructura de directorios y archivos de manera recursiva
for directorio_actual, directorios, archivos in os.walk(ruta_carpeta):
    # Verificar si hay archivos con extensión .json en este directorio
    if any(archivo.endswith('.json') for archivo in archivos):
        # Mostrar el directorio actual
        print("\n\n\n\n")
        print("Directorio con archivos .json:", directorio_actual)
        separacion_de_directorio = directorio_actual.split("\\")
        print(f"Directorio_separado: {separacion_de_directorio}")
        # Recorrer los archivos en este directorio
        for archivo in archivos:
            # Verificar si el archivo tiene extensión .json
            if archivo.endswith('.json'):
                # Mostrar el nombre del archivo .json
                print("Nombre del archivo .json:", archivo)
                directorio_json = directorio_actual + "\\" + archivo
                with open(directorio_json, "r") as archivo:
                    datos = json.load(archivo)
                    datos_data = pd.DataFrame.from_dict(datos, orient = 'index')
                    print(datos_data)
                    directorio_de_guardado_pd = directorio_actual + "\\" + separacion_de_directorio[-1] + ".xlsx"
                    directorio_de_guardado_pd_1 = directorio_actual + "\\" + separacion_de_directorio[-1] + "_dataframe" + ".csv"
                    print(f"Dataframe_almacenado en: {directorio_de_guardado_pd}")
                    datos_data.to_excel(directorio_de_guardado_pd, index=True)  # Guardar el DataFrame sin incluir el índice
                    datos_data.to_csv(directorio_de_guardado_pd_1, index=True)  # Guardar el DataFrame sin incluir el índice
# Out:
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_11_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_cruz', 'KNN_val_cruz_11_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.310839         0.326667      0.310839
# Experimento_LR_10_test_3          0.312129         0.332612      0.312129
# Experimento_LR_10_test_4          0.314968         0.332836      0.314968
# Experimento_LR_10_test_5          0.308516         0.325760      0.308516
# Experimento_LR_10_test_6          0.304645         0.323729      0.304645
# Experimento_LR_10_test_7          0.306452         0.323347      0.306452
# Experimento_LR_10_test_8          0.306194         0.324913      0.306194
# Experimento_LR_10_test_9          0.308774         0.326920      0.308774
# Experimento_LR_10_test_10         0.301677         0.317121      0.301677
#
#                            f1_media
# Experimento_LR_10_test_2   0.296404
# Experimento_LR_10_test_3   0.299560
# Experimento_LR_10_test_4   0.301812
# Experimento_LR_10_test_5   0.294844
# Experimento_LR_10_test_6   0.292191
# Experimento_LR_10_test_7   0.293433
# Experimento_LR_10_test_8   0.293255
# Experimento_LR_10_test_9   0.296731
# Experimento_LR_10_test_10  0.288194
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_11_vecinos\KNN_val_cruz_11_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_13_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_cruz', 'KNN_val_cruz_13_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.321935         0.346227      0.321935
# Experimento_LR_10_test_3          0.320000         0.347846      0.320000
# Experimento_LR_10_test_4          0.320258         0.349052      0.320258
# Experimento_LR_10_test_5          0.316000         0.342640      0.316000
# Experimento_LR_10_test_6          0.320258         0.347727      0.320258
# Experimento_LR_10_test_7          0.321677         0.349229      0.321677
# Experimento_LR_10_test_8          0.321677         0.348414      0.321677
# Experimento_LR_10_test_9          0.321419         0.346768      0.321419
# Experimento_LR_10_test_10         0.322323         0.348126      0.322323
#
#                            f1_media
# Experimento_LR_10_test_2   0.309179
# Experimento_LR_10_test_3   0.308440
# Experimento_LR_10_test_4   0.308699
# Experimento_LR_10_test_5   0.303898
# Experimento_LR_10_test_6   0.308948
# Experimento_LR_10_test_7   0.310359
# Experimento_LR_10_test_8   0.309440
# Experimento_LR_10_test_9   0.309858
# Experimento_LR_10_test_10  0.309723
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_13_vecinos\KNN_val_cruz_13_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_15_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_cruz', 'KNN_val_cruz_15_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.324516         0.343775      0.324516
# Experimento_LR_10_test_3          0.329677         0.348381      0.329677
# Experimento_LR_10_test_4          0.326194         0.348486      0.326194
# Experimento_LR_10_test_5          0.326194         0.349133      0.326194
# Experimento_LR_10_test_6          0.325161         0.343890      0.325161
# Experimento_LR_10_test_7          0.327484         0.350481      0.327484
# Experimento_LR_10_test_8          0.327355         0.349516      0.327355
# Experimento_LR_10_test_9          0.327742         0.349964      0.327742
# Experimento_LR_10_test_10         0.325032         0.348487      0.325032
#
#                            f1_media
# Experimento_LR_10_test_2   0.312742
# Experimento_LR_10_test_3   0.317869
# Experimento_LR_10_test_4   0.314720
# Experimento_LR_10_test_5   0.313534
# Experimento_LR_10_test_6   0.313331
# Experimento_LR_10_test_7   0.317294
# Experimento_LR_10_test_8   0.316415
# Experimento_LR_10_test_9   0.317081
# Experimento_LR_10_test_10  0.313826
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_15_vecinos\KNN_val_cruz_15_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_3_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_cruz', 'KNN_val_cruz_3_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.272516         0.304320      0.272516
# Experimento_LR_10_test_3          0.265032         0.302328      0.265032
# Experimento_LR_10_test_4          0.269032         0.307709      0.269032
# Experimento_LR_10_test_5          0.267613         0.306463      0.267613
# Experimento_LR_10_test_6          0.266194         0.300512      0.266194
# Experimento_LR_10_test_7          0.272645         0.311155      0.272645
# Experimento_LR_10_test_8          0.269161         0.304182      0.269161
# Experimento_LR_10_test_9          0.265419         0.301502      0.265419
# Experimento_LR_10_test_10         0.267226         0.306173      0.267226
#
#                            f1_media
# Experimento_LR_10_test_2   0.246533
# Experimento_LR_10_test_3   0.243636
# Experimento_LR_10_test_4   0.247805
# Experimento_LR_10_test_5   0.246347
# Experimento_LR_10_test_6   0.245338
# Experimento_LR_10_test_7   0.251013
# Experimento_LR_10_test_8   0.247309
# Experimento_LR_10_test_9   0.244359
# Experimento_LR_10_test_10  0.246372
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_3_vecinos\KNN_val_cruz_3_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_5_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_cruz', 'KNN_val_cruz_5_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.281032         0.297844      0.281032
# Experimento_LR_10_test_3          0.280129         0.301043      0.280129
# Experimento_LR_10_test_4          0.278839         0.296418      0.278839
# Experimento_LR_10_test_5          0.279613         0.297251      0.279613
# Experimento_LR_10_test_6          0.278710         0.296980      0.278710
# Experimento_LR_10_test_7          0.280774         0.297960      0.280774
# Experimento_LR_10_test_8          0.280129         0.296197      0.280129
# Experimento_LR_10_test_9          0.277161         0.293411      0.277161
# Experimento_LR_10_test_10         0.279871         0.298726      0.279871
#
#                            f1_media
# Experimento_LR_10_test_2   0.265346
# Experimento_LR_10_test_3   0.265728
# Experimento_LR_10_test_4   0.263376
# Experimento_LR_10_test_5   0.264771
# Experimento_LR_10_test_6   0.263523
# Experimento_LR_10_test_7   0.264692
# Experimento_LR_10_test_8   0.264006
# Experimento_LR_10_test_9   0.261188
# Experimento_LR_10_test_10  0.264061
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_5_vecinos\KNN_val_cruz_5_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_7_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_cruz', 'KNN_val_cruz_7_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.298065         0.323819      0.298065
# Experimento_LR_10_test_3          0.296000         0.328553      0.296000
# Experimento_LR_10_test_4          0.302581         0.333822      0.302581
# Experimento_LR_10_test_5          0.301677         0.325808      0.301677
# Experimento_LR_10_test_6          0.299742         0.325907      0.299742
# Experimento_LR_10_test_7          0.297548         0.325089      0.297548
# Experimento_LR_10_test_8          0.297806         0.323451      0.297806
# Experimento_LR_10_test_9          0.299613         0.324139      0.299613
# Experimento_LR_10_test_10         0.297419         0.324152      0.297419
#
#                            f1_media
# Experimento_LR_10_test_2   0.279520
# Experimento_LR_10_test_3   0.277711
# Experimento_LR_10_test_4   0.286171
# Experimento_LR_10_test_5   0.284656
# Experimento_LR_10_test_6   0.283719
# Experimento_LR_10_test_7   0.282023
# Experimento_LR_10_test_8   0.282451
# Experimento_LR_10_test_9   0.284374
# Experimento_LR_10_test_10  0.282525
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_7_vecinos\KNN_val_cruz_7_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_9_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_cruz', 'KNN_val_cruz_9_vecinos']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.305935         0.327767      0.305935
# Experimento_LR_10_test_3          0.302968         0.327651      0.302968
# Experimento_LR_10_test_4          0.304387         0.327522      0.304387
# Experimento_LR_10_test_5          0.301548         0.324260      0.301548
# Experimento_LR_10_test_6          0.299355         0.322424      0.299355
# Experimento_LR_10_test_7          0.300000         0.322942      0.300000
# Experimento_LR_10_test_8          0.297419         0.319660      0.297419
# Experimento_LR_10_test_9          0.300000         0.320036      0.300000
# Experimento_LR_10_test_10         0.299097         0.319773      0.299097
#
#                            f1_media
# Experimento_LR_10_test_2   0.292665
# Experimento_LR_10_test_3   0.289365
# Experimento_LR_10_test_4   0.291640
# Experimento_LR_10_test_5   0.289298
# Experimento_LR_10_test_6   0.286620
# Experimento_LR_10_test_7   0.286889
# Experimento_LR_10_test_8   0.284592
# Experimento_LR_10_test_9   0.287845
# Experimento_LR_10_test_10  0.286237
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_cruz\KNN_val_cruz_9_vecinos\KNN_val_cruz_9_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_11_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_sim', 'KNN_val_simple_11_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.131613   0.135838  0.131613  0.121843
# Experimento_LR_2_test_0.2   0.142581   0.136812  0.142581  0.131866
# Experimento_LR_3_test_0.3   0.160860   0.165681  0.160860  0.152853
# Experimento_LR_4_test_0.4   0.171613   0.169490  0.171613  0.163160
# Experimento_LR_5_test_0.5   0.192000   0.189625  0.192000  0.182415
# Experimento_LR_6_test_0.6   0.201290   0.204936  0.201290  0.194875
# Experimento_LR_7_test_0.7   0.225438   0.225105  0.225438  0.218141
# Experimento_LR_8_test_0.8   0.244677   0.248037  0.244677  0.236128
# Experimento_LR_9_test_0.9   0.268244   0.270300  0.268244  0.259130
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_11_vecinos\KNN_val_simple_11_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_13_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_sim', 'KNN_val_simple_13_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.157419   0.149508  0.157419  0.142334
# Experimento_LR_2_test_0.2   0.161290   0.154064  0.161290  0.149771
# Experimento_LR_3_test_0.3   0.170753   0.164788  0.170753  0.159277
# Experimento_LR_4_test_0.4   0.183871   0.182004  0.183871  0.176044
# Experimento_LR_5_test_0.5   0.200516   0.200995  0.200516  0.190849
# Experimento_LR_6_test_0.6   0.220860   0.222347  0.220860  0.212415
# Experimento_LR_7_test_0.7   0.243134   0.245692  0.243134  0.235351
# Experimento_LR_8_test_0.8   0.252742   0.256938  0.252742  0.244298
# Experimento_LR_9_test_0.9   0.271971   0.274546  0.271971  0.263231
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_13_vecinos\KNN_val_simple_13_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_15_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_sim', 'KNN_val_simple_15_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.163871   0.167127  0.163871  0.151043
# Experimento_LR_2_test_0.2   0.158710   0.155007  0.158710  0.148869
# Experimento_LR_3_test_0.3   0.176774   0.171336  0.176774  0.164957
# Experimento_LR_4_test_0.4   0.190000   0.187392  0.190000  0.180286
# Experimento_LR_5_test_0.5   0.217548   0.220199  0.217548  0.208414
# Experimento_LR_6_test_0.6   0.232258   0.234243  0.232258  0.223714
# Experimento_LR_7_test_0.7   0.251797   0.254883  0.251797  0.243448
# Experimento_LR_8_test_0.8   0.257903   0.264136  0.257903  0.249829
# Experimento_LR_9_test_0.9   0.285305   0.288171  0.285305  0.276324
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_15_vecinos\KNN_val_simple_15_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_3_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_sim', 'KNN_val_simple_3_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.007742   0.044130  0.007742  0.006152
# Experimento_LR_2_test_0.2   0.018065   0.029518  0.018065  0.014916
# Experimento_LR_3_test_0.3   0.032258   0.036094  0.032258  0.026553
# Experimento_LR_4_test_0.4   0.057419   0.057892  0.057419  0.048544
# Experimento_LR_5_test_0.5   0.084387   0.081963  0.084387  0.073235
# Experimento_LR_6_test_0.6   0.111183   0.106373  0.111183  0.098631
# Experimento_LR_7_test_0.7   0.143963   0.142969  0.143963  0.133389
# Experimento_LR_8_test_0.8   0.179839   0.179774  0.179839  0.167806
# Experimento_LR_9_test_0.9   0.206452   0.206448  0.206452  0.192868
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_3_vecinos\KNN_val_simple_3_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_5_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_sim', 'KNN_val_simple_5_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.072258   0.048794  0.072258  0.057523
# Experimento_LR_2_test_0.2   0.069032   0.054825  0.069032  0.059303
# Experimento_LR_3_test_0.3   0.080000   0.071616  0.080000  0.072442
# Experimento_LR_4_test_0.4   0.104194   0.096998  0.104194  0.097145
# Experimento_LR_5_test_0.5   0.125677   0.119907  0.125677  0.119004
# Experimento_LR_6_test_0.6   0.141290   0.136474  0.141290  0.135526
# Experimento_LR_7_test_0.7   0.169032   0.166191  0.169032  0.164317
# Experimento_LR_8_test_0.8   0.197419   0.196399  0.197419  0.192085
# Experimento_LR_9_test_0.9   0.236559   0.234729  0.236559  0.229774
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_5_vecinos\KNN_val_simple_5_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_7_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_sim', 'KNN_val_simple_7_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.082581   0.065459  0.082581  0.072103
# Experimento_LR_2_test_0.2   0.091613   0.087304  0.091613  0.083034
# Experimento_LR_3_test_0.3   0.106237   0.101527  0.106237  0.096337
# Experimento_LR_4_test_0.4   0.130000   0.126356  0.130000  0.120971
# Experimento_LR_5_test_0.5   0.154581   0.150365  0.154581  0.145482
# Experimento_LR_6_test_0.6   0.176344   0.174519  0.176344  0.168239
# Experimento_LR_7_test_0.7   0.195392   0.193138  0.195392  0.188770
# Experimento_LR_8_test_0.8   0.221935   0.222464  0.221935  0.214529
# Experimento_LR_9_test_0.9   0.244588   0.245780  0.244588  0.236942
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_7_vecinos\KNN_val_simple_7_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_9_vecinos
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'KNN_val_sim', 'KNN_val_simple_9_vecinos']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.107097   0.098785  0.107097  0.093651
# Experimento_LR_2_test_0.2   0.121290   0.110424  0.121290  0.108996
# Experimento_LR_3_test_0.3   0.134194   0.130724  0.134194  0.124952
# Experimento_LR_4_test_0.4   0.155806   0.152780  0.155806  0.148216
# Experimento_LR_5_test_0.5   0.174710   0.169779  0.174710  0.165197
# Experimento_LR_6_test_0.6   0.194409   0.191889  0.194409  0.186967
# Experimento_LR_7_test_0.7   0.211244   0.210682  0.211244  0.205152
# Experimento_LR_8_test_0.8   0.234032   0.234769  0.234032  0.226710
# Experimento_LR_9_test_0.9   0.261362   0.261210  0.261362  0.253589
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\KNN_val_sim\KNN_val_simple_9_vecinos\KNN_val_simple_9_vecinos.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_1000_0.0001_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'LSTM_Neural_Network', 'RNN_1000_0.0001_0.7']
# Nombre del archivo .json: metricas_1000_0.0001_0.1.json
#                          0
# accuracy          0.363871
# precission        0.388454
# recall            0.361368
# f1                0.368908
# loss              0.000308
# train_accunrancy  0.998996
# test_accyrancy    0.363871
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_1000_0.0001_0.7\RNN_1000_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_1000_0.0001_0.2.json
#                          0
# accuracy          0.349677
# precission        0.355337
# recall            0.352063
# f1                0.348760
# loss              0.000138
# train_accunrancy  0.998065
# test_accyrancy    0.349677
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_1000_0.0001_0.7\RNN_1000_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_1000_0.0001_0.3.json
#                          0
# accuracy          0.306237
# precission        0.351754
# recall            0.304893
# f1                0.314603
# loss              0.003735
# train_accunrancy  0.998894
# test_accyrancy    0.306237
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_1000_0.0001_0.7\RNN_1000_0.0001_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_1000_1e-05_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'LSTM_Neural_Network', 'RNN_1000_1e-05_0.7']
# Nombre del archivo .json: metricas_1000_1e-05_0.1.json
#                          0
# accuracy          0.409032
# precission        0.410139
# recall            0.410295
# f1                0.402176
# loss              0.005620
# train_accunrancy  0.992258
# test_accyrancy    0.409032
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_1000_1e-05_0.7\RNN_1000_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_1000_1e-05_0.2.json
#                          0
# accuracy          0.294194
# precission        0.290302
# recall            0.294691
# f1                0.286945
# loss              0.104836
# train_accunrancy  0.987903
# test_accyrancy    0.294194
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_1000_1e-05_0.7\RNN_1000_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_1000_1e-05_0.3.json
#                          0
# accuracy          0.373333
# precission        0.386957
# recall            0.374235
# f1                0.377821
# loss              0.024626
# train_accunrancy  0.978433
# test_accyrancy    0.373333
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_1000_1e-05_0.7\RNN_1000_1e-05_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_100_0.0001_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'LSTM_Neural_Network', 'RNN_100_0.0001_0.7']
# Nombre del archivo .json: metricas_100_0.0001_0.1.json
#                          0
# accuracy          0.456774
# precission        0.461030
# recall            0.451576
# f1                0.454558
# loss              0.244719
# train_accunrancy  0.974480
# test_accyrancy    0.456774
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_100_0.0001_0.7\RNN_100_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_100_0.0001_0.2.json
#                          0
# accuracy          0.391613
# precission        0.387978
# recall            0.394002
# f1                0.381010
# loss              0.070529
# train_accunrancy  0.975484
# test_accyrancy    0.391613
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_100_0.0001_0.7\RNN_100_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_100_0.0001_0.3.json
#                          0
# accuracy          0.313548
# precission        0.306455
# recall            0.314730
# f1                0.303458
# loss              0.109702
# train_accunrancy  0.975300
# test_accyrancy    0.313548
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_100_0.0001_0.7\RNN_100_0.0001_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_100_1e-05_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'LSTM_Neural_Network', 'RNN_100_1e-05_0.7']
# Nombre del archivo .json: metricas_100_1e-05_0.1.json
#                          0
# accuracy          0.424516
# precission        0.336588
# recall            0.410580
# f1                0.310218
# loss              1.063108
# train_accunrancy  0.444588
# test_accyrancy    0.424516
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_100_1e-05_0.7\RNN_100_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_100_1e-05_0.2.json
#                          0
# accuracy          0.367097
# precission        0.250809
# recall            0.361416
# f1                0.262098
# loss              1.353776
# train_accunrancy  0.389677
# test_accyrancy    0.367097
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_100_1e-05_0.7\RNN_100_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_100_1e-05_0.3.json
#                          0
# accuracy          0.366022
# precission        0.297140
# recall            0.367104
# f1                0.323402
# loss              1.282310
# train_accunrancy  0.458065
# test_accyrancy    0.366022
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_100_1e-05_0.7\RNN_100_1e-05_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_300_0.0001_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'LSTM_Neural_Network', 'RNN_300_0.0001_0.7']
# Nombre del archivo .json: metricas_300_0.0001_0.1.json
#                          0
# accuracy          0.388387
# precission        0.417323
# recall            0.387962
# f1                0.392645
# loss              0.016517
# train_accunrancy  0.994552
# test_accyrancy    0.388387
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_300_0.0001_0.7\RNN_300_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_300_0.0001_0.2.json
#                          0
# accuracy          0.381290
# precission        0.401660
# recall            0.383138
# f1                0.386763
# loss              0.012881
# train_accunrancy  0.992903
# test_accyrancy    0.381290
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_300_0.0001_0.7\RNN_300_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_300_0.0001_0.3.json
#                          0
# accuracy          0.375914
# precission        0.410818
# recall            0.376081
# f1                0.385105
# loss              0.002456
# train_accunrancy  0.990415
# test_accyrancy    0.375914
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_300_0.0001_0.7\RNN_300_0.0001_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_300_1e-05_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'LSTM_Neural_Network', 'RNN_300_1e-05_0.7']
# Nombre del archivo .json: metricas_300_1e-05_0.1.json
#                          0
# accuracy          0.407742
# precission        0.397676
# recall            0.402665
# f1                0.396768
# loss              0.373508
# train_accunrancy  0.872545
# test_accyrancy    0.407742
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_300_1e-05_0.7\RNN_300_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_300_1e-05_0.2.json
#                          0
# accuracy          0.444516
# precission        0.430858
# recall            0.442407
# f1                0.435457
# loss              0.460690
# train_accunrancy  0.880645
# test_accyrancy    0.444516
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_300_1e-05_0.7\RNN_300_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_300_1e-05_0.3.json
#                          0
# accuracy          0.457634
# precission        0.454424
# recall            0.456277
# f1                0.454958
# loss              0.351202
# train_accunrancy  0.885714
# test_accyrancy    0.457634
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_300_1e-05_0.7\RNN_300_1e-05_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_500_0.0001_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'LSTM_Neural_Network', 'RNN_500_0.0001_0.7']
# Nombre del archivo .json: metricas_500_0.0001_0.1.json
#                          0
# accuracy          0.401290
# precission        0.433338
# recall            0.407997
# f1                0.399966
# loss              0.007338
# train_accunrancy  0.998853
# test_accyrancy    0.401290
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_500_0.0001_0.7\RNN_500_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_500_0.0001_0.2.json
#                          0
# accuracy          0.359355
# precission        0.428753
# recall            0.360167
# f1                0.376333
# loss              0.004051
# train_accunrancy  0.998548
# test_accyrancy    0.359355
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_500_0.0001_0.7\RNN_500_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_500_0.0001_0.3.json
#                          0
# accuracy          0.320000
# precission        0.342241
# recall            0.323059
# f1                0.322406
# loss              0.008677
# train_accunrancy  0.993733
# test_accyrancy    0.320000
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_500_0.0001_0.7\RNN_500_0.0001_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_500_1e-05_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'LSTM_Neural_Network', 'RNN_500_1e-05_0.7']
# Nombre del archivo .json: metricas_500_1e-05_0.1.json
#                          0
# accuracy          0.370323
# precission        0.371553
# recall            0.375301
# f1                0.369602
# loss              0.190481
# train_accunrancy  0.959713
# test_accyrancy    0.370323
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_500_1e-05_0.7\RNN_500_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_500_1e-05_0.2.json
#                          0
# accuracy          0.361935
# precission        0.347534
# recall            0.357121
# f1                0.349227
# loss              0.201005
# train_accunrancy  0.945645
# test_accyrancy    0.361935
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_500_1e-05_0.7\RNN_500_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_500_1e-05_0.3.json
#                          0
# accuracy          0.409032
# precission        0.398851
# recall            0.404188
# f1                0.400548
# loss              0.068756
# train_accunrancy  0.961290
# test_accyrancy    0.409032
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_500_1e-05_0.7\RNN_500_1e-05_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_700_0.0001_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'LSTM_Neural_Network', 'RNN_700_0.0001_0.7']
# Nombre del archivo .json: metricas_700_0.0001_0.1.json
#                          0
# accuracy          0.362581
# precission        0.383729
# recall            0.366177
# f1                0.366332
# loss              0.004687
# train_accunrancy  0.997849
# test_accyrancy    0.362581
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_700_0.0001_0.7\RNN_700_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_700_0.0001_0.2.json
#                          0
# accuracy          0.311613
# precission        0.336119
# recall            0.311849
# f1                0.316906
# loss              0.000689
# train_accunrancy  0.998710
# test_accyrancy    0.311613
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_700_0.0001_0.7\RNN_700_0.0001_0.7.xlsx
# Nombre del archivo .json: metricas_700_0.0001_0.3.json
#                          0
# accuracy          0.326022
# precission        0.334297
# recall            0.323583
# f1                0.325160
# loss              0.004238
# train_accunrancy  0.998710
# test_accyrancy    0.326022
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_700_0.0001_0.7\RNN_700_0.0001_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_700_1e-05_0.7
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'LSTM_Neural_Network', 'RNN_700_1e-05_0.7']
# Nombre del archivo .json: metricas_700_1e-05_0.1.json
#                          0
# accuracy          0.380645
# precission        0.344966
# recall            0.366685
# f1                0.346550
# loss              0.210246
# train_accunrancy  0.977634
# test_accyrancy    0.380645
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_700_1e-05_0.7\RNN_700_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_700_1e-05_0.2.json
#                          0
# accuracy          0.378065
# precission        0.347416
# recall            0.380061
# f1                0.354457
# loss              0.038519
# train_accunrancy  0.989839
# test_accyrancy    0.378065
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_700_1e-05_0.7\RNN_700_1e-05_0.7.xlsx
# Nombre del archivo .json: metricas_700_1e-05_0.3.json
#                          0
# accuracy          0.404301
# precission        0.406975
# recall            0.403888
# f1                0.404165
# loss              0.181968
# train_accunrancy  0.945991
# test_accyrancy    0.404301
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\LSTM_Neural_Network\RNN_700_1e-05_0.7\RNN_700_1e-05_0.7.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_1000_0.0001_0.1
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Neural_network_classification', 'RRN_1000_0.0001_0.1']
# Nombre del archivo .json: resultados_1000_0.0001_0.1.json
#                   0
# accuracy   0.459785
# precision  0.480315
# recall     0.459151
# f1         0.467444
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_1000_0.0001_0.1\RRN_1000_0.0001_0.1.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_1000_0.0001_0.2
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Neural_network_classification', 'RRN_1000_0.0001_0.2']
# Nombre del archivo .json: resultados_1000_0.0001_0.2.json
#                   0
# accuracy   0.471398
# precision  0.521481
# recall     0.471471
# f1         0.484975
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_1000_0.0001_0.2\RRN_1000_0.0001_0.2.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_1000_0.0001_0.3
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Neural_network_classification', 'RRN_1000_0.0001_0.3']
# Nombre del archivo .json: resultados_1000_0.0001_0.3.json
#                   0
# accuracy   0.477419
# precision  0.530727
# recall     0.476575
# f1         0.491356
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_1000_0.0001_0.3\RRN_1000_0.0001_0.3.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_1000_1e-05_0.1
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Neural_network_classification', 'RRN_1000_1e-05_0.1']
# Nombre del archivo .json: resultados_1000_1e-05_0.1.json
#                   0
# accuracy   0.471398
# precision  0.483158
# recall     0.470510
# f1         0.473134
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_1000_1e-05_0.1\RRN_1000_1e-05_0.1.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_1000_1e-05_0.2
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Neural_network_classification', 'RRN_1000_1e-05_0.2']
# Nombre del archivo .json: resultados_1000_1e-05_0.2.json
#                   0
# accuracy   0.437419
# precision  0.442860
# recall     0.435816
# f1         0.436824
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_1000_1e-05_0.2\RRN_1000_1e-05_0.2.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_1000_1e-05_0.3
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Neural_network_classification', 'RRN_1000_1e-05_0.3']
# Nombre del archivo .json: resultados_1000_1e-05_0.3.json
#                   0
# accuracy   0.449462
# precision  0.446113
# recall     0.447852
# f1         0.446404
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_1000_1e-05_0.3\RRN_1000_1e-05_0.3.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_100_0.0001_0.1
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Neural_network_classification', 'RRN_100_0.0001_0.1']
# Nombre del archivo .json: resultados_100_0.0001_0.1.json
#                   0
# accuracy   0.449462
# precision  0.487467
# recall     0.448767
# f1         0.460991
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_100_0.0001_0.1\RRN_100_0.0001_0.1.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_100_0.0001_0.2
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Neural_network_classification', 'RRN_100_0.0001_0.2']
# Nombre del archivo .json: resultados_100_0.0001_0.2.json
#                   0
# accuracy   0.507097
# precision  0.536728
# recall     0.506098
# f1         0.514741
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_100_0.0001_0.2\RRN_100_0.0001_0.2.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_100_0.0001_0.3
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Neural_network_classification', 'RRN_100_0.0001_0.3']
# Nombre del archivo .json: resultados_100_0.0001_0.3.json
#                   0
# accuracy   0.444301
# precision  0.482515
# recall     0.445653
# f1         0.452791
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_100_0.0001_0.3\RRN_100_0.0001_0.3.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_100_1e-05_0.1
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Neural_network_classification', 'RRN_100_1e-05_0.1']
# Nombre del archivo .json: resultados_100_1e-05_0.1.json
#                   0
# accuracy   0.423656
# precision  0.417505
# recall     0.418383
# f1         0.417779
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_100_1e-05_0.1\RRN_100_1e-05_0.1.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_100_1e-05_0.2
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Neural_network_classification', 'RRN_100_1e-05_0.2']
# Nombre del archivo .json: resultados_100_1e-05_0.2.json
#                   0
# accuracy   0.445591
# precision  0.431778
# recall     0.444195
# f1         0.435044
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_100_1e-05_0.2\RRN_100_1e-05_0.2.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Neural_network_classification\RRN_100_1e-05_0.3
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Neural_network_classification', 'RRN_100_1e-05_0.3']
# Nombre del archivo .json: resultados_100_1e-05_0.3.json
#                   0
# accuracy   0.430538
# precision  0.417981
# recall     0.428493
# f1         0.421259
# ...
# Nombre del archivo .json: random_forest_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.451484         0.455127      0.451484
# Experimento_LR_10_test_3          0.454452         0.459715      0.454452
# Experimento_LR_10_test_4          0.461935         0.471099      0.461935
# Experimento_LR_10_test_5          0.455226         0.463729      0.455226
# Experimento_LR_10_test_6          0.461677         0.467805      0.461677
# Experimento_LR_10_test_7          0.474581         0.481323      0.474581
# Experimento_LR_10_test_8          0.465677         0.472690      0.465677
# Experimento_LR_10_test_9          0.465161         0.475132      0.465161
# Experimento_LR_10_test_10         0.461935         0.468063      0.461935
#
#                            f1_media
# Experimento_LR_10_test_2   0.451715
# Experimento_LR_10_test_3   0.453831
# Experimento_LR_10_test_4   0.463320
# Experimento_LR_10_test_5   0.455704
# Experimento_LR_10_test_6   0.462265
# Experimento_LR_10_test_7   0.474459
# Experimento_LR_10_test_8   0.466183
# Experimento_LR_10_test_9   0.466815
# Experimento_LR_10_test_10  0.462025
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_cruz\Random_Forest_val_cruz_6_estimators\Random_Forest_val_cruz_6_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_cruz\Random_Forest_val_cruz_8_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Random_Forest_val_cruz', 'Random_Forest_val_cruz_8_estimators']
# Nombre del archivo .json: random_forest_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.477806         0.480169      0.477806
# Experimento_LR_10_test_3          0.479484         0.484100      0.479484
# Experimento_LR_10_test_4          0.474839         0.478864      0.474839
# Experimento_LR_10_test_5          0.482968         0.488071      0.482968
# Experimento_LR_10_test_6          0.490452         0.495065      0.490452
# Experimento_LR_10_test_7          0.491613         0.494324      0.491613
# Experimento_LR_10_test_8          0.489161         0.492511      0.489161
# Experimento_LR_10_test_9          0.493677         0.495463      0.493677
# Experimento_LR_10_test_10         0.496258         0.500474      0.496258
#
#                            f1_media
# Experimento_LR_10_test_2   0.476051
# Experimento_LR_10_test_3   0.478416
# Experimento_LR_10_test_4   0.474295
# Experimento_LR_10_test_5   0.481954
# Experimento_LR_10_test_6   0.489819
# Experimento_LR_10_test_7   0.490410
# Experimento_LR_10_test_8   0.487529
# Experimento_LR_10_test_9   0.492128
# Experimento_LR_10_test_10  0.495229
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_cruz\Random_Forest_val_cruz_8_estimators\Random_Forest_val_cruz_8_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_simp\Random_Forest_val_sim_10_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Random_Forest_val_simp', 'Random_Forest_val_sim_10_estimators']
# Nombre del archivo .json: random_forest_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.406452   0.416098  0.406452  0.407776
# Experimento_LR_2_test_0.2   0.424516   0.432310  0.424516  0.424022
# Experimento_LR_3_test_0.3   0.421935   0.432961  0.421935  0.424598
# Experimento_LR_4_test_0.4   0.424516   0.428193  0.424516  0.423203
# Experimento_LR_5_test_0.5   0.444129   0.448437  0.444129  0.440979
# Experimento_LR_6_test_0.6   0.420430   0.421331  0.420430  0.420169
# Experimento_LR_7_test_0.7   0.424147   0.423978  0.424147  0.422185
# Experimento_LR_8_test_0.8   0.404677   0.413522  0.404677  0.407153
# Experimento_LR_9_test_0.9   0.375341   0.378055  0.375341  0.375364
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_simp\Random_Forest_val_sim_10_estimators\Random_Forest_val_sim_10_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_simp\Random_Forest_val_sim_1_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Random_Forest_val_simp', 'Random_Forest_val_sim_1_estimators']
# Nombre del archivo .json: random_forest_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.321290   0.322782  0.321290  0.321739
# Experimento_LR_2_test_0.2   0.366452   0.368776  0.366452  0.366800
# Experimento_LR_3_test_0.3   0.360430   0.360295  0.360430  0.360193
# Experimento_LR_4_test_0.4   0.308387   0.306657  0.308387  0.307157
# Experimento_LR_5_test_0.5   0.324903   0.324646  0.324903  0.324217
# Experimento_LR_6_test_0.6   0.320215   0.319305  0.320215  0.319586
# Experimento_LR_7_test_0.7   0.312442   0.314517  0.312442  0.312651
# Experimento_LR_8_test_0.8   0.274839   0.279371  0.274839  0.273464
# Experimento_LR_9_test_0.9   0.296918   0.298769  0.296918  0.295659
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_simp\Random_Forest_val_sim_1_estimators\Random_Forest_val_sim_1_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_simp\Random_Forest_val_sim_2_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Random_Forest_val_simp', 'Random_Forest_val_sim_2_estimators']
# Nombre del archivo .json: random_forest_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.321290   0.369803  0.321290  0.309665
# Experimento_LR_2_test_0.2   0.301290   0.332623  0.301290  0.287679
# Experimento_LR_3_test_0.3   0.280000   0.308476  0.280000  0.259431
# Experimento_LR_4_test_0.4   0.320968   0.345309  0.320968  0.300335
# Experimento_LR_5_test_0.5   0.323871   0.350185  0.323871  0.311741
# Experimento_LR_6_test_0.6   0.310323   0.320639  0.310323  0.290965
# Experimento_LR_7_test_0.7   0.305069   0.335333  0.305069  0.289432
# Experimento_LR_8_test_0.8   0.300000   0.325903  0.300000  0.278828
# Experimento_LR_9_test_0.9   0.276272   0.301549  0.276272  0.258490
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_simp\Random_Forest_val_sim_2_estimators\Random_Forest_val_sim_2_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_simp\Random_Forest_val_sim_4_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Random_Forest_val_simp', 'Random_Forest_val_sim_4_estimators']
# Nombre del archivo .json: random_forest_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.357419   0.362276  0.357419  0.352871
# Experimento_LR_2_test_0.2   0.368387   0.375653  0.368387  0.363375
# Experimento_LR_3_test_0.3   0.370753   0.383623  0.370753  0.369272
# Experimento_LR_4_test_0.4   0.364516   0.373443  0.364516  0.363874
# Experimento_LR_5_test_0.5   0.375742   0.380116  0.375742  0.373835
# Experimento_LR_6_test_0.6   0.369892   0.378028  0.369892  0.367797
# Experimento_LR_7_test_0.7   0.373088   0.373840  0.373088  0.370910
# Experimento_LR_8_test_0.8   0.339516   0.346955  0.339516  0.339320
# Experimento_LR_9_test_0.9   0.366165   0.375686  0.366165  0.364500
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_simp\Random_Forest_val_sim_4_estimators\Random_Forest_val_sim_4_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_simp\Random_Forest_val_sim_6_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Random_Forest_val_simp', 'Random_Forest_val_sim_6_estimators']
# Nombre del archivo .json: random_forest_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.396129   0.409884  0.396129  0.397231
# Experimento_LR_2_test_0.2   0.423871   0.433440  0.423871  0.424360
# Experimento_LR_3_test_0.3   0.406452   0.410879  0.406452  0.404299
# Experimento_LR_4_test_0.4   0.403871   0.413206  0.403871  0.403000
# Experimento_LR_5_test_0.5   0.400000   0.404787  0.400000  0.397545
# Experimento_LR_6_test_0.6   0.404301   0.411304  0.404301  0.402521
# Experimento_LR_7_test_0.7   0.400000   0.398906  0.400000  0.398629
# Experimento_LR_8_test_0.8   0.378710   0.390400  0.378710  0.377902
# Experimento_LR_9_test_0.9   0.353835   0.359693  0.353835  0.354184
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_simp\Random_Forest_val_sim_6_estimators\Random_Forest_val_sim_6_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_simp\Random_Forest_val_sim_8_estimators
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Random_Forest_val_simp', 'Random_Forest_val_sim_8_estimators']
# Nombre del archivo .json: random_forest_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.449032   0.460710  0.449032  0.452046
# Experimento_LR_2_test_0.2   0.440645   0.450280  0.440645  0.440827
# Experimento_LR_3_test_0.3   0.421935   0.432396  0.421935  0.422411
# Experimento_LR_4_test_0.4   0.403871   0.412482  0.403871  0.404736
# Experimento_LR_5_test_0.5   0.438452   0.442520  0.438452  0.436689
# Experimento_LR_6_test_0.6   0.417634   0.424483  0.417634  0.415051
# Experimento_LR_7_test_0.7   0.426175   0.429664  0.426175  0.425910
# Experimento_LR_8_test_0.8   0.373548   0.387323  0.373548  0.375503
# Experimento_LR_9_test_0.9   0.371756   0.382274  0.371756  0.371838
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Random_Forest_val_simp\Random_Forest_val_sim_8_estimators\Random_Forest_val_sim_8_estimators.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Regresion_Logistica_val_cruz
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Regresion_Logistica_val_cruz']
# Nombre del archivo .json: regresion_logistica_val_cruz.json
#                            exactitud_media  precision_media  recall_media  \
# Experimento_LR_10_test_2          0.674968         0.681837      0.674968
# Experimento_LR_10_test_3          0.685677         0.692985      0.685677
# Experimento_LR_10_test_4          0.689419         0.696576      0.689419
# Experimento_LR_10_test_5          0.689161         0.695868      0.689161
# Experimento_LR_10_test_6          0.695871         0.702963      0.695871
# Experimento_LR_10_test_7          0.693290         0.700036      0.693290
# Experimento_LR_10_test_8          0.694452         0.700381      0.694452
# Experimento_LR_10_test_9          0.696645         0.703551      0.696645
# Experimento_LR_10_test_10         0.698194         0.704050      0.698194
#
#                            f1_media
# Experimento_LR_10_test_2   0.670507
# Experimento_LR_10_test_3   0.681428
# Experimento_LR_10_test_4   0.685040
# Experimento_LR_10_test_5   0.684422
# Experimento_LR_10_test_6   0.691437
# Experimento_LR_10_test_7   0.689025
# Experimento_LR_10_test_8   0.689967
# Experimento_LR_10_test_9   0.692296
# Experimento_LR_10_test_10  0.693831
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Regresion_Logistica_val_cruz\Regresion_Logistica_val_cruz.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Regresion_Logistica_val_simple
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Regresion_Logistica_val_simple']
# Nombre del archivo .json: regresion_logistica_val_simple.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.571613   0.571832  0.571613  0.568234
# Experimento_LR_2_test_0.2   0.559355   0.555855  0.559355  0.555553
# Experimento_LR_3_test_0.3   0.551398   0.554371  0.551398  0.550418
# Experimento_LR_4_test_0.4   0.536129   0.540744  0.536129  0.535890
# Experimento_LR_5_test_0.5   0.520258   0.520610  0.520258  0.518684
# Experimento_LR_6_test_0.6   0.500000   0.498331  0.500000  0.498028
# Experimento_LR_7_test_0.7   0.484608   0.484485  0.484608  0.483539
# Experimento_LR_8_test_0.8   0.435968   0.453480  0.435968  0.439840
# Experimento_LR_9_test_0.9   0.401864   0.411403  0.401864  0.402004
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Regresion_Logistica_val_simple\Regresion_Logistica_val_simple.xlsx
#
#
#
#
#
# Directorio con archivos .json: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Regresion_Logistica_val_simple\.ipynb_checkpoints
# Directorio_separado: ['F:', 'nuevo_conocimiento', 'CODIGO DE TESIS (MUY IMPORTANTE)', 'Experimentos_con_modelos_basicos', 'TF_IDF_embeddings', 'Regresion_Logistica_val_simple', '.ipynb_checkpoints']
# Nombre del archivo .json: regresion_logistica_val_simple-checkpoint.json
#                            exactitud  precision    recall        f1
# Experimento_LR_1_test_0.1   0.571613   0.571832  0.571613  0.568234
# Experimento_LR_2_test_0.2   0.559355   0.555855  0.559355  0.555553
# Experimento_LR_3_test_0.3   0.551398   0.554371  0.551398  0.550418
# Experimento_LR_4_test_0.4   0.536129   0.540744  0.536129  0.535890
# Experimento_LR_5_test_0.5   0.520258   0.520610  0.520258  0.518684
# Experimento_LR_6_test_0.6   0.500000   0.498331  0.500000  0.498028
# Experimento_LR_7_test_0.7   0.484608   0.484485  0.484608  0.483539
# Experimento_LR_8_test_0.8   0.435968   0.453480  0.435968  0.439840
# Experimento_LR_9_test_0.9   0.401864   0.411403  0.401864  0.402004
# Dataframe_almacenado en: F:\nuevo_conocimiento\CODIGO DE TESIS (MUY IMPORTANTE)\Experimentos_con_modelos_basicos\TF_IDF_embeddings\Regresion_Logistica_val_simple\.ipynb_checkpoints\.ipynb_checkpoints.xlsx

# %%
"
